# %% [markdown]
# SVM for baseline performance on image classification

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, svm, metrics
import os
import glob
import tqdm

# %%
train_path = "../project-data/train_another/"
val_path = "../project-data/validation_another/"
img_size = 128
nchannels = 3

npz_file_listing_train = list(glob.glob(os.path.join(train_path, '**/*.npz')))
npz_file_listing_val = list(glob.glob(os.path.join(val_path, '**/*.npz')))
N_train = len(npz_file_listing_train)
N_val = len(npz_file_listing_val)

training_data_X = np.zeros((N_train, img_size, img_size, nchannels))
training_data_y = np.zeros(N_train)
val_data_X = np.zeros((N_val, img_size, img_size, nchannels))
val_data_y = np.zeros(N_val)

it = 0
for npz_file in tqdm.tqdm(npz_file_listing_train):
    training_data_X[it, :, :, :] = np.load(npz_file)['pixels']
    if "no_" in npz_file:
        training_data_y[it] = 0
    else:
        training_data_y[it] = 1
    it += 1
    
it = 0
for npz_file in tqdm.tqdm(npz_file_listing_val):
    val_data_X[it, :, :, :] = np.load(npz_file)['pixels']
    if "no_" in npz_file:
        val_data_y[it] = 0
    else:
        val_data_y[it] = 1
    it += 1
# Out:
# ...
# 100%|██████████| 2000/2000 [00:07<00:00, 275.02it/s]

# %%
# check to see if this worked
print("labels:", np.unique(training_data_y, return_counts=True))
single_im = training_data_X[9, :, :, :]
plt.imshow(single_im/255)
plt.title("loaded image sample")
plt.show()
# cool, yup!
# Out:
# labels: (array([0., 1.]), array([5000, 5000]))

# %%
# in order to train an SVM, I want to reshape the data so it's in the form (nsamples, nfeatures)
N_features = img_size * img_size * nchannels
training_data_X_reshape = np.zeros((N_train, N_features))
val_data_X_reshape = np.zeros((N_val, N_features))
for i in tqdm.tqdm(range(N_train)):
    training_data_X_reshape[i, :] = np.reshape(training_data_X[i,:,:,:], (1, N_features))
    
for i in tqdm.tqdm(range(N_val)):
    val_data_X_reshape[i, :] = np.reshape(val_data_X[i,:,:,:], (1, N_features))
# Out:
# ...
# 100%|██████████| 2000/2000 [00:04<00:00, 470.26it/s]

# %%
# now let's train a support vector machine with just the raw data as inputs
small_idx = np.random.randint(0, training_data_X_reshape.shape[0], size=1000)
small_X = training_data_X_reshape[small_idx,:]
small_y = training_data_y[small_idx]
raw_clf_small = svm.SVC(verbose=True)
raw_clf_small.fit(small_X, small_y)
# raw_clf.fit(training_data_X_reshape, training_data_y)
# Out:
# [LibSVM]
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=True)

# %%
small_y_pred = raw_clf_small.predict(small_X)
print(np.sum(small_y_pred == small_y)/small_y.shape[0])
# Out:
# 0.941

# %%
small_y_val_pred = raw_clf_small.predict(val_data_X_reshape)
val_acc = np.sum(small_y_val_pred == val_data_y)/small_y_val_pred.shape[0]
print("Validation accuracy:", val_acc)
# Out:
# Validation accuracy: 0.7565

# %%
# full SVM on all data
raw_clf = svm.SVC(verbose=True)
raw_clf.fit(training_data_X_reshape, training_data_y)
y_pred_train = raw_clf.predict(training_data_X_reshape)
y_pred_val = raw_clf.predict(val_data_X_reshape)
train_acc = np.sum(y_pred_train == training_data_y)/y_pred_train.shape[0]
val_acc = np.sum(y_pred_val == val_data_y)/y_pred_val.shape[0]
print("Training Accuracy: ", train_acc)
print("Validation Accuracy: ", val_acc)
# Out:
# [LibSVM]

# %%
# feature engineering

# %%
# shallow neural net
